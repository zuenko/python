# %%
import pandas as pd
import numpy as np
import scipy.stats as sts

import matplotlib.pyplot as plt
import pylab

import os

# %%
defen = pd.read_excel('Data_Extract_From_Gender_Statistics.xlsx', sheetname=1, encoding = 'utf8').append(pd.read_excel('Data_Extract_From_Health_Nutrition_and_Population_Statistics.xlsx', sheetname=1, encoding='utf8')).append(pd.read_excel('Data_Extract_From_Millennium_Development_Goals.xlsx', sheetname=1, encoding='utf8'))

# %%
def D_maker(data,c=0.5, p=0.01, m=1, s=u'Корреляция'):
    rez=[]
    for index in data.index:
        for column in data.columns:
            i_tmp = index.split(':')
            c_tmp = column.split(':')
            value=[]
            
            if i_tmp[2]!=u'p-value' and i_tmp[0]!=c_tmp[0]:
                value.append([data.get_value(index=index, col=column),data.get_value(index=i_tmp[0]+':'+i_tmp[1]+':p-value', col=column)])
                
                if abs(value[0][0])>c and value[0][1]<p and abs(value[0][0])<m:
                    
                    if [defen[defen['Code']==c_tmp[0]]['Indicator Name'].tolist()[0], defen[defen['Code']==i_tmp[0]]['Indicator Name'].tolist()[0], value[0][0]] not in rez:
                        rez.append([defen[defen['Code']==i_tmp[0]]['Indicator Name'].tolist()[0], defen[defen['Code']==c_tmp[0]]['Indicator Name'].tolist()[0], value[0][0]])
                    
                    #Degbug                    
                    #return rez
    db = pd.DataFrame().append(rez)
    db.columns = [u'Первый признак', u'Второй признак', u'Корреляция']
    #print (len(db))
    db = check(db.sort_values(by=[s]))
    return db

def check(data):
    rez=[]
    data = data.sort_values(by=[u'Корреляция'])
    tmp = data.as_matrix()
    for i, row in enumerate(tmp):
        if i<len(tmp)-1:
            if row[2] != tmp[i+1][2] and row[1] != tmp[i+1][0] and row[0] != tmp[i+1][1]:
                rez.append(row)
    if len(rez)!=0:
        db = pd.DataFrame().append(rez)
        db.columns = [u'Первый признак', u'Второй признак', u'Корреляция']
        return db.reset_index()
    else:
        print('what?')
        return data
            

def to_ex(data, filename):
    data[[u'Первый признак', u'Второй признак', u'Корреляция']].sort_values(by=u'Первый признак').to_excel(filename, sheet_name=filename.split('.')[1], index = False)

def Sumup(d_name):
    files = os.listdir(d_name)
    rez = pd.DataFrame(columns = [u'Первый признак', u'Второй признак', u'Корреляция'])
    for name in files:
        n_count = name.split('.')[1].split('_')[2]
        filename = name.split('.')[2]+'.'+n_count+'.Con.xlsx'
        print (n_count)
        if filename not in os.listdir('Conclusion'):
            print('inside!', filename)
            data = pd.read_excel(d_name+'/'+name ,encoding = 'utf8')
            if len(data)>4:
                to_ex(D_maker(data), filename)

# %% [markdown]
# to_ex(D_maker(pd.read_excel('deep.Corr_in_RUS.Eastern Europe.xlsx', encoding='utf8')), 'check-t1', 'RUS')

# %%
Sumup('Correlations')
# Out:
# ABW
# AFG
# AGO
# ALB
# AND
# ARB
# ARE
# ARG
# ARM
# ATG
# AUS
# AUT
# AZE
# BDI
# BEL
# BEN
# BFA
# BGD
# BGR
# BHR
# BHS
# BIH
# BLR
# BLZ
# BMU
# BOL
# BRA
# BRB
# BRN
# BTN
# BWA
# CAF
# CAN
# CEB
# CHE
# CHI
# CHL
# CHN
# CIV
# CMR
# COD
# COG
# COL
# COM
# CPV
# CRI
# CSS
# CUB
# CUW
# CYM
# CYP
# CZE
# DEU
# DJI
# DMA
# DNK
# DOM
# DZA
# EAP
# EAR
# EAS
# ECA
# ECS
# ECU
# EGY
# EMU
# ERI
# ESP
# EST
# ETH
# EUU
# FCS
# FIN
# FJI
# FRA
# FRO
# FSM
# GAB
# GBR
# GEO
# GHA
# GIB
# inside! Southern Europe.GIB.Con.xlsx
# GIN
# GMB
# inside! nan.GMB.Con.xlsx
# GNB
# GNQ
# GRC
# GRD
# inside! Caribbean.GRD.Con.xlsx
# GRL
# inside! Northern America.GRL.Con.xlsx
# GTM
# GUM
# inside! Micronesia.GUM.Con.xlsx
# GUY
# HIC
# HKG
# inside! nan.HKG.Con.xlsx
# HND
# HPC
# inside! nan.HPC.Con.xlsx
# HRV
# HTI
# HUN
# inside! Eastern Europe.HUN.Con.xlsx
# IBD
# inside! nan.IBD.Con.xlsx
# IBT
# IDA
# inside! nan.IDA.Con.xlsx
# IDB
# inside! nan.IDB.Con.xlsx
# IDN
# inside! South-Eastern Asia.IDN.Con.xlsx
# IDX
# IMN
# inside! Northern Europe.IMN.Con.xlsx
# IND
# inside! Southern Asia.IND.Con.xlsx
# IRL
# IRN
# IRQ
# inside! Western Asia.IRQ.Con.xlsx
# ISL
# inside! Northern Europe.ISL.Con.xlsx
# ISR
# inside! Western Asia.ISR.Con.xlsx
# ITA
# JAM
# JOR
# JPN
# KAZ
# KEN
# inside! Eastern Africa.KEN.Con.xlsx
# KGZ
# KHM
# inside! South-Eastern Asia.KHM.Con.xlsx
# KIR
# inside! Micronesia.KIR.Con.xlsx
# KNA
# inside! nan.KNA.Con.xlsx
# KOR
# inside! nan.KOR.Con.xlsx
# KWT
# inside! Western Asia.KWT.Con.xlsx
# LAC
# inside! nan.LAC.Con.xlsx
# LAO
# LBN
# LBR
# LBY
# inside! Northern Africa.LBY.Con.xlsx
# LCA
# inside! nan.LCA.Con.xlsx
# LCN
# inside! nan.LCN.Con.xlsx
# LDC
# inside! nan.LDC.Con.xlsx
# LIC
# LIE
# inside! Western Europe.LIE.Con.xlsx
# LKA
# inside! Southern Asia.LKA.Con.xlsx
# LMC
# inside! nan.LMC.Con.xlsx
# LMY
# LSO
# LTE
# inside! nan.LTE.Con.xlsx
# LTU
# inside! Northern Europe.LTU.Con.xlsx
# LUX
# inside! Western Europe.LUX.Con.xlsx
# LVA
# inside! Northern Europe.LVA.Con.xlsx
# MAC
# inside! nan.MAC.Con.xlsx
# MAF
# inside! nan.MAF.Con.xlsx
# MAR
# MCO
# inside! Western Europe.MCO.Con.xlsx
# MDA
# MDG
# inside! Eastern Africa.MDG.Con.xlsx
# MDV
# inside! Southern Asia.MDV.Con.xlsx
# MEA
# inside! nan.MEA.Con.xlsx
# MEX
# MHL
# inside! Micronesia.MHL.Con.xlsx
# MIC
# MKD
# inside! nan.MKD.Con.xlsx
# MLI
# inside! Western Africa.MLI.Con.xlsx
# MLT
# inside! Southern Europe.MLT.Con.xlsx
# MMR
# inside! South-Eastern Asia.MMR.Con.xlsx
# MNA
# MNE
# inside! Southern Europe.MNE.Con.xlsx
# MNG
# MNP
# inside! Micronesia.MNP.Con.xlsx
# MOZ
# inside! Eastern Africa.MOZ.Con.xlsx
# MRT
# inside! Western Africa.MRT.Con.xlsx
# MUS
# inside! Eastern Africa.MUS.Con.xlsx
# MWI
# inside! Eastern Africa.MWI.Con.xlsx
# MYS
# inside! South-Eastern Asia.MYS.Con.xlsx
# NAC
# inside! nan.NAC.Con.xlsx
# NAM
# inside! Southern Africa.NAM.Con.xlsx
# NCL
# inside! Melanesia.NCL.Con.xlsx
# NER
# NGA
# NIC
# NLD
# NOR
# NPL
# NRU
# inside! Micronesia.NRU.Con.xlsx
# NZL
# inside! Australia and New Zealand.NZL.Con.xlsx
# OED
# inside! nan.OED.Con.xlsx
# OMN
# OSS
# PAK
# PAN
# PER
# inside! South America.PER.Con.xlsx
# PHL
# inside! South-Eastern Asia.PHL.Con.xlsx
# PLW
# inside! Micronesia.PLW.Con.xlsx
# PNG
# inside! Melanesia.PNG.Con.xlsx
# POL
# inside! Eastern Europe.POL.Con.xlsx
# PRE
# inside! nan.PRE.Con.xlsx
# PRI
# PRK
# inside! nan.PRK.Con.xlsx
# PRT
# inside! Southern Europe.PRT.Con.xlsx
# PRY
# PSE
# inside! nan.PSE.Con.xlsx
# PSS
# inside! nan.PSS.Con.xlsx
# PST
# inside! nan.PST.Con.xlsx
# PYF
# inside! Polynesia.PYF.Con.xlsx
# QAT
# ROU
# inside! Eastern Europe.ROU.Con.xlsx
# RUS
# RWA
# SAS
# SAU
# SDN
# inside! Northern Africa.SDN.Con.xlsx
# SEN
# SGP
# inside! South-Eastern Asia.SGP.Con.xlsx
# SLB
# inside! Melanesia.SLB.Con.xlsx
# SLE
# inside! Western Africa.SLE.Con.xlsx
# SLV
# SMR
# inside! Southern Europe.SMR.Con.xlsx
# SOM
# SRB
# SSA
# SSD
# SSF
# SST
# inside! nan.SST.Con.xlsx
# STP
# inside! Middle Africa.STP.Con.xlsx
# SUR
# SVK
# SVN
# inside! Southern Europe.SVN.Con.xlsx
# SWE
# SWZ
# inside! Southern Africa.SWZ.Con.xlsx
# SXM
# inside! Caribbean.SXM.Con.xlsx
# SYC
# inside! Eastern Africa.SYC.Con.xlsx
# SYR
# inside! Western Asia.SYR.Con.xlsx
# TCA
# inside! Caribbean.TCA.Con.xlsx
# TCD
# TEA
# inside! nan.TEA.Con.xlsx
# TEC
# inside! nan.TEC.Con.xlsx
# TGO
# THA
# TJK
# inside! Central Asia.TJK.Con.xlsx
# TKM
# TLA
# inside! nan.TLA.Con.xlsx
# TLS
# inside! South-Eastern Asia.TLS.Con.xlsx
# TMN
# TON
# inside! Polynesia.TON.Con.xlsx
# TSA
# inside! nan.TSA.Con.xlsx
# TSS
# inside! nan.TSS.Con.xlsx
# TTO
# TUN
# TUR
# TUV
# inside! Polynesia.TUV.Con.xlsx
# TZA
# UGA
# UKR
# inside! Eastern Europe.UKR.Con.xlsx
# UMC
# URY
# USA
# inside! nan.USA.Con.xlsx
# UZB
# inside! Central Asia.UZB.Con.xlsx
# VCT
# inside! nan.VCT.Con.xlsx
# VEN
# VGB
# inside! nan.VGB.Con.xlsx
# VIR
# inside! Caribbean.VIR.Con.xlsx
# VNM
# VUT
# inside! Melanesia.VUT.Con.xlsx
# WLD
# WSM
# inside! Polynesia.WSM.Con.xlsx
# XKX
# YEM
# ZAF
# ZMB
# inside! Eastern Africa.ZMB.Con.xlsx
# ZWE
# inside! Eastern Africa.ZWE.Con.xlsx
