# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import TimeSeriesSplit, cross_val_score

from sklearn.linear_model import LinearRegression, ElasticNet, BayesianRidge, SGDRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor, ExtraTreesRegressor, BaggingRegressor, AdaBoostRegressor

from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor, ExtraTreeRegressor

from sklearn.svm import LinearSVR

from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor

import datetime
from tqdm import tqdm_notebook

# %% [markdown]
# # Load

# %%
X = np.load('data/X.npy')
y = np.load('data/y.npy')

# %% [markdown]
# # Finding best model
# Et tu, Bruteforce?

# %%
def calculate_cv(X, y):
    cv = TimeSeriesSplit(n_splits=4)
    results = {
        'lr': [],
        'el_net': [],
        'bayes_ridge': [],
        'sgd': [],
        'gbr': [],
        'rf': [],
        'ext': [],
        'bag_reg': [],
        'abr': [],
        'kn': [],
        'dtr': [],
        'etr': [],
        'svm': [],
        'xgb': [],
        'lgb': [],
        'cat': [],
    }
    
    lr = LinearRegression()
    el_net = ElasticNet()
    bayes_ridge = BayesianRidge()
    sgd = SGDRegressor()
    
    gbr = GradientBoostingRegressor() 
    rf = RandomForestRegressor()
    ext = ExtraTreeRegressor()
    bag_reg = BaggingRegressor()
    abr = AdaBoostRegressor()
    
    kn = KNeighborsRegressor(n_neighbors = 3, weights='uniform', p = 1)
    
    dtr = DecisionTreeRegressor()
    etr = ExtraTreeRegressor()
    
    svm = LinearSVR()
    
    xgb = XGBRegressor()
    lgb = LGBMRegressor()
    cat = CatBoostRegressor()
    
    results['lr'].append(cross_val_score(lr, X, y, cv=cv, scoring='neg_mean_absolute_error', n_jobs=-1).mean())
    results['el_net'].append(cross_val_score(el_net, X, y, cv=cv, scoring='neg_mean_absolute_error', n_jobs=-1).mean())
    results['bayes_ridge'].append(cross_val_score(bayes_ridge, X, y, cv=cv, scoring='neg_mean_absolute_error', n_jobs=-1).mean())
    results['sgd'].append(cross_val_score(sgd, X, y, cv=cv, scoring='neg_mean_absolute_error', n_jobs=-1).mean())
    results['gbr'].append(cross_val_score(gbr, X, y, cv=cv, scoring='neg_mean_absolute_error', n_jobs=-1).mean())
    results['rf'].append(cross_val_score(rf, X, y, cv=cv, scoring='neg_mean_absolute_error', n_jobs=-1).mean())
    results['ext'].append(cross_val_score(ext, X, y, cv=cv, scoring='neg_mean_absolute_error', n_jobs=-1).mean())
    results['bag_reg'].append(cross_val_score(bag_reg, X, y, cv=cv, scoring='neg_mean_absolute_error', n_jobs=-1).mean())
    results['abr'].append(cross_val_score(abr, X, y, cv=cv, scoring='neg_mean_absolute_error', n_jobs=-1).mean())
    results['kn'].append(cross_val_score(kn, X, y, cv=cv, scoring='neg_mean_absolute_error', n_jobs=-1).mean())
    results['dtr'].append(cross_val_score(dtr, X, y, cv=cv, scoring='neg_mean_absolute_error', n_jobs=-1).mean())
    results['etr'].append(cross_val_score(etr, X, y, cv=cv, scoring='neg_mean_absolute_error', n_jobs=-1).mean())
    results['svm'].append(cross_val_score(svm, X, y, cv=cv, scoring='neg_mean_absolute_error', n_jobs=-1).mean())
    results['xgb'].append(cross_val_score(xgb, X, y, cv=cv, scoring='neg_mean_absolute_error', n_jobs=-1).mean())
    results['lgb'].append(cross_val_score(lgb, X, y, cv=cv, scoring='neg_mean_absolute_error', n_jobs=-1, fit_params = {}).mean())
    results['cat'].append(cross_val_score(cat, X, y, cv=cv, scoring='neg_mean_absolute_error', n_jobs=-1).mean())    
    
    for key in list(results.keys()):
        print (f'Mean absolute error: {abs(results[key][0])}, algorithm: {key}')

# %%
calculate_cv(X,y)
# Out:
# Mean absolute error: 48.2986788097265, algorithm: lr
# Mean absolute error: 36.80135163757205, algorithm: el_net
# Mean absolute error: 32.450379000236154, algorithm: bayes_ridge
# Mean absolute error: 4088007294844225.5, algorithm: sgd
# Mean absolute error: 43.74809939966454, algorithm: gbr
# Mean absolute error: 41.119642857142864, algorithm: rf
# Mean absolute error: 27.29017857142857, algorithm: ext
# Mean absolute error: 44.824553571428574, algorithm: bag_reg
# Mean absolute error: 49.766815358044965, algorithm: abr
# Mean absolute error: 15.930059523809522, algorithm: kn
# Mean absolute error: 46.98214285714286, algorithm: dtr
# Mean absolute error: 44.89732142857142, algorithm: etr
# Mean absolute error: 37.60330003163385, algorithm: svm
# Mean absolute error: 44.5396576160565, algorithm: xgb
# Mean absolute error: 28.590413747547903, algorithm: lgb
# Mean absolute error: 27.593352975861876, algorithm: cat

# %% [markdown]
# ## Autoregressions

# %%
from sklearn.metrics import mean_absolute_error

from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARMA, ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
data = pd.read_csv('data/train_target.csv', index_col= 0)

# %%
def check_auto_reg(data):
    cv = TimeSeriesSplit(n_splits=4)
    
    score = []
    for train_ind, test_ind in cv.split(data):
        model = AR(data['target'][train_ind])
        model_fit = model.fit()
        yhat = model_fit.predict(start = str(data.index[test_ind[0]]), end = str(data.index[test_ind[-1]]))
        score.append(mean_absolute_error(data['target'][test_ind], yhat))
    print ('Autoregression: ', np.mean(score))
    
    score = []
    for train_ind, test_ind in cv.split(data):
        model = ARMA(data['target'][train_ind], order=(0, 1))
        model_fit = model.fit()
        yhat = model_fit.predict(start = str(data.index[test_ind[0]]), end = str(data.index[test_ind[-1]]))
        score.append(mean_absolute_error(data['target'][test_ind], yhat))
    print ('Moving Average: ', np.mean(score))
    
    score = []
    for train_ind, test_ind in cv.split(data):
        model = ARIMA(data['target'][train_ind], order=(1, 1, 1))
        model_fit = model.fit(disp=False)
        yhat = model_fit.predict(start = str(data.index[test_ind[0]]), end = str(data.index[test_ind[-1]]))
        score.append(mean_absolute_error(data['target'][test_ind], yhat))
    print ('Autoregressive Integrated Moving Average: ', np.mean(score))

# %%
check_auto_reg(data)
# Out:
# /home/denis/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   % freq, ValueWarning)
# /home/denis/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   % freq, ValueWarning)
# /home/denis/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   % freq, ValueWarning)
# /home/denis/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   % freq, ValueWarning)
# /home/denis/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   % freq, ValueWarning)
# /home/denis/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   % freq, ValueWarning)
# /home/denis/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   % freq, ValueWarning)
# Autoregression:  46.56476301663901
# Moving Average:  43.19917643445923
# /home/denis/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   % freq, ValueWarning)
# /home/denis/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   % freq, ValueWarning)
# /home/denis/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   % freq, ValueWarning)
# /home/denis/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   % freq, ValueWarning)
# /home/denis/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   % freq, ValueWarning)
# /home/denis/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   % freq, ValueWarning)
# /home/denis/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   % freq, ValueWarning)
# Autoregressive Integrated Moving Average:  25.15649791511033
# /home/denis/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   % freq, ValueWarning)
# /home/denis/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   % freq, ValueWarning)

# %% [markdown]
# ## A bit feature-engineering

# %%
from sklearn.cluster import KMeans

# %%
X_clus = np.concatenate((KMeans(3).fit_transform(X,y), X), axis=1)

# %%
calculate_cv(X_clus,y)
# Out:
# Mean absolute error: 45.08147507897011, algorithm: lr
# Mean absolute error: 32.373093070777244, algorithm: el_net
# Mean absolute error: 28.02465636019223, algorithm: bayes_ridge
# Mean absolute error: 6254070102932415.0, algorithm: sgd
# Mean absolute error: 32.227814492090154, algorithm: gbr
# Mean absolute error: 37.44642857142857, algorithm: rf
# Mean absolute error: 46.05357142857143, algorithm: ext
# Mean absolute error: 39.33928571428571, algorithm: bag_reg
# Mean absolute error: 38.86564891009197, algorithm: abr
# Mean absolute error: 17.08482142857143, algorithm: kn
# Mean absolute error: 41.34375, algorithm: dtr
# Mean absolute error: 21.522321428571427, algorithm: etr
# Mean absolute error: 43.44484351310867, algorithm: svm
# Mean absolute error: 32.8727540006595, algorithm: xgb
# Mean absolute error: 20.669529125413288, algorithm: lgb
# Mean absolute error: 19.518386711670676, algorithm: cat

# %%
X_clus_num = np.concatenate((KMeans().fit_transform(pd.read_csv('data/train_num_cols.csv').values, y), X), axis=1)

# %%
calculate_cv(X_clus_num, y)
# Out:
# Mean absolute error: 47.122344856870576, algorithm: lr
# Mean absolute error: 32.98369070247763, algorithm: el_net
# Mean absolute error: 30.705852229412223, algorithm: bayes_ridge
# Mean absolute error: 5104723973062055.0, algorithm: sgd
# Mean absolute error: 41.93763662981808, algorithm: gbr
# Mean absolute error: 40.98571428571428, algorithm: rf
# Mean absolute error: 48.83482142857143, algorithm: ext
# Mean absolute error: 44.575892857142854, algorithm: bag_reg
# Mean absolute error: 48.76214003410852, algorithm: abr
# Mean absolute error: 16.941964285714285, algorithm: kn
# Mean absolute error: 40.558035714285715, algorithm: dtr
# Mean absolute error: 44.848214285714285, algorithm: etr
# Mean absolute error: 30.673275612551794, algorithm: svm
# Mean absolute error: 42.45413471119745, algorithm: xgb
# Mean absolute error: 34.77319411196585, algorithm: lgb
# Mean absolute error: 27.84343806055621, algorithm: cat

# %% [markdown]
# ## Bonus (just for fun)

# %%
import torch

# %%
device = torch.device('cuda')

# N is batch size; D_in is input dimension;
# H is hidden dimension; D_out is output dimension.
D_in, D_out = 15, 1

X_tensor = torch.tensor(X, device=device)
y_tensor = torch.tensor(y, device=device)

class Net(nn.Module):

    def __init__(self, input_dim, hidden_dims):
        super(Net, self).__init__()
        layers = []
        
        for i in range(len(hidden_dims)):
            layers.append(nn.Linear(input_dim, hidden_dims[i]))
            layers.append(nn.ReLU())
            # layers.append(nn.LSTM(input_dim, hidden_dims[i], i))
            input_dim = hidden_dims[i]
        
        
        self.net = nn.Sequential(*layers)
        self.out = nn.Linear(input_dim, 1)
        
        
    def forward(self, x):
        x = self.out(self.net(x))
        
        return x

model = Net(D_in, [4, 8, 16]).to(device)

model = model.double()

loss_fn = torch.nn.L1Loss(reduction='sum')
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

best_loss = np.inf
losses = []
for t in range(200000):
    y_pred = model(x)

    loss = loss_fn(y_pred, y_tensor.double().view(282, 1))
    if (t+1)%10000 == 0: 
        print(t+1, loss.item())
    
    if best_loss > loss:
        best_loss = loss
        torch.save({'state_dict': model.state_dict()}, 'checkpoint.pth')
        
    losses.append(np.float(loss))
    model.zero_grad()
    loss.backward()
    optimizer.step()
    
print (best_loss)
# Out:
# 10000 8470.28891199592
# 20000 8470.128911995951
# 30000 8470.108808014062
# 40000 8470.528911996014
# 50000 8470.368911996045
# 60000 8470.208911996078
# 70000 8470.04891199611
# 80000 8470.38880801351
# 90000 8470.44891199617
# 100000 8470.288911996202
# 110000 8470.128911996235
# 120000 8470.108808013067
# 130000 8470.528911996298
# 140000 8470.368911996331
# 150000 8470.20891199636
# 160000 8470.048911996393
# 170000 8470.388808012514
# 180000 8470.448911996456
# 190000 8470.28891199649
# 200000 8470.12891199652
# tensor(8470.0489, device='cuda:0', dtype=torch.float64, grad_fn=<L1LossBackward>)

# %% [markdown]
# Not worked :(

# %% [markdown]
# ## Hyperparam tuning

# %%
from sklearn.model_selection import train_test_split
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
import colorama, hyperopt

import catboost

# %%
N_HYPEROPT_PROBES = 1000

HYPEROPT_ALGO = tpe.suggest  #  tpe.suggest OR hyperopt.rand.suggest

colorama.init()

X_test, y_test = X_clus[-30:], y[-30:]
X_train, X_val, y_train, y_val = train_test_split(X_clus[:-30], y[:-30], test_size=0.2, shuffle = False)

D_train = catboost.Pool(X_train, y_train)
D_val = catboost.Pool(X_val, y_val)

# %%
def get_catboost_params(space):
    params = dict()
    params['iterations'] = space['iterations']
    params['learning_rate'] = space['learning_rate']
    params['depth'] = int(space['depth'])
    params['l2_leaf_reg'] = space['l2_leaf_reg']
    params['rsm'] = space['rsm']
    params['ctr_leaf_count_limit'] = space['ctr_leaf_count_limit']
    params['bootstrap_type'] = space['bootstrap_type']
    #params['subsample'] = space['subsample']
    return params


obj_call_count = 0
cur_best_loss = np.inf
log_writer = open( 'catboost-hyperopt-log.txt', 'w' )

def objective(space):
    global obj_call_count, cur_best_loss

    obj_call_count += 1

    #print('\nCatBoost objective call #{} cur_best_loss={:7.5f}'.format(obj_call_count,cur_best_loss))

    params = get_catboost_params(space)

    sorted_params = sorted(space.items(), key=lambda z: z[0])
    params_str = str.join(' ', ['{}={}'.format(k, v) for k, v in sorted_params])
    #print('Params: {}'.format(params_str) )

    model = catboost.CatBoostRegressor(loss_function = 'MAE',
                                       store_all_simple_ctr = True,
                                       early_stopping_rounds=10,
                                       iterations = params['iterations'],
                                       learning_rate = params['learning_rate'],
                                       depth = params['depth'],
                                       l2_leaf_reg = params['l2_leaf_reg'],
                                       rsm = params['rsm'],
                                       ctr_leaf_count_limit = params['ctr_leaf_count_limit'],
                                       bootstrap_type = params['bootstrap_type'],
                                       random_seed = 42,
                                       #subsample = params['subsample'],
                                      )
    
    model.fit(D_train, eval_set=D_val, verbose=False)

    y_pred = model.predict(X_test)

    test_loss = mean_absolute_error(y_test, y_pred)
    
    log_writer.write('MAE={}\n'.format(test_loss))
    log_writer.flush()

    if test_loss<cur_best_loss:
        cur_best_loss = test_loss
        print(colorama.Fore.GREEN + 'NEW BEST LOSS={}'.format(cur_best_loss) + colorama.Fore.RESET)
        print('Params: {}'.format(params_str) )


    return{'loss':test_loss, 'status': STATUS_OK }

# %%
space ={
        'iterations': hp.quniform('iterations', 50, 1000, 20),
        'depth': hp.quniform("depth", 4, 12, 1),
        'rsm': hp.uniform ('rsm', 0.5, 1.0),
        'learning_rate': hp.loguniform('learning_rate', -3.0, -0.7),
        'l2_leaf_reg': hp.uniform('l2_leaf_reg', 1, 10),
        'ctr_leaf_count_limit': hp.quniform('ctr_leaf_count_limit', 1, 20, 1),
        'bootstrap_type': hp.choice('bootstrap_type', ['Bayesian', 'Bernoulli']),
        #'subsample': hp.uniform('subsample', .0, 1.0),
       }

trials = Trials()
best = hyperopt.fmin(fn=objective,
                     space=space,
                     algo=HYPEROPT_ALGO,
                     max_evals=N_HYPEROPT_PROBES,
                     trials=trials, verbose = 2)

print('-'*50)
print('The best params:')
print( best )
print('\n\n')
# Out:
# NEW BEST LOSS=20.861983127285733
# Params: bootstrap_type=Bernoulli ctr_leaf_count_limit=11.0 depth=10.0 iterations=340.0 l2_leaf_reg=5.845430869436142 learning_rate=0.3826332485512357 rsm=0.7962306140036166
# NEW BEST LOSS=18.7288824071468
# Params: bootstrap_type=Bernoulli ctr_leaf_count_limit=5.0 depth=5.0 iterations=340.0 l2_leaf_reg=2.7185698896238755 learning_rate=0.3230156328989772 rsm=0.6138346001411772
# NEW BEST LOSS=17.46315801867186
# Params: bootstrap_type=Bernoulli ctr_leaf_count_limit=9.0 depth=4.0 iterations=840.0 l2_leaf_reg=3.6104446734595887 learning_rate=0.2005468311301181 rsm=0.8910682940126395
# NEW BEST LOSS=17.400122400473396
# Params: bootstrap_type=Bernoulli ctr_leaf_count_limit=13.0 depth=4.0 iterations=980.0 l2_leaf_reg=4.123677219946936 learning_rate=0.18389737399099534 rsm=0.70991086524094
# NEW BEST LOSS=16.733745576748053
# Params: bootstrap_type=Bernoulli ctr_leaf_count_limit=12.0 depth=4.0 iterations=1000.0 l2_leaf_reg=1.195653898872027 learning_rate=0.17494820817403373 rsm=0.7221154390739294
# NEW BEST LOSS=16.26996864541341
# Params: bootstrap_type=Bernoulli ctr_leaf_count_limit=18.0 depth=4.0 iterations=940.0 l2_leaf_reg=1.8721114329826278 learning_rate=0.21719689986875637 rsm=0.5210337649859414
# NEW BEST LOSS=15.939184970070901
# Params: bootstrap_type=Bernoulli ctr_leaf_count_limit=10.0 depth=4.0 iterations=800.0 l2_leaf_reg=3.256122406833067 learning_rate=0.49385874928364176 rsm=0.7389941378705723
# NEW BEST LOSS=15.629728830849347
# Params: bootstrap_type=Bernoulli ctr_leaf_count_limit=13.0 depth=4.0 iterations=960.0 l2_leaf_reg=1.45830581406563 learning_rate=0.38551705207803993 rsm=0.8335688239309106
# NEW BEST LOSS=15.203810756220587
# Params: bootstrap_type=Bernoulli ctr_leaf_count_limit=13.0 depth=4.0 iterations=940.0 l2_leaf_reg=1.4843600132545316 learning_rate=0.336240247122616 rsm=0.9536044708397406
# NEW BEST LOSS=15.157203691392413
# Params: bootstrap_type=Bernoulli ctr_leaf_count_limit=17.0 depth=4.0 iterations=960.0 l2_leaf_reg=1.4394800446372817 learning_rate=0.4046420340899414 rsm=0.9001892543613947
# NEW BEST LOSS=15.151858269710392
# Params: bootstrap_type=Bernoulli ctr_leaf_count_limit=14.0 depth=4.0 iterations=980.0 l2_leaf_reg=1.1599145641109747 learning_rate=0.334903159789426 rsm=0.9924119808477811
# NEW BEST LOSS=14.90345868340902
# Params: bootstrap_type=Bernoulli ctr_leaf_count_limit=9.0 depth=4.0 iterations=940.0 l2_leaf_reg=1.0199156183159344 learning_rate=0.3540279113483776 rsm=0.9082805427362257
# --------------------------------------------------
# The best params:
# {'bootstrap_type': 1, 'ctr_leaf_count_limit': 9.0, 'depth': 4.0, 'iterations': 940.0, 'l2_leaf_reg': 1.0199156183159344, 'learning_rate': 0.3540279113483776, 'rsm': 0.9082805427362257}

# %% [markdown]
# # Predict

# %%
X_test = np.load('data/X_test.npy')

km = KMeans(3).fit(X,y) 

X_clus_test = np.concatenate((km.transform(X_test), X_test), axis=1) 

D_train = catboost.Pool(X_clus, y)

model = catboost.CatBoostRegressor(loss_function = 'MAE',
                                   store_all_simple_ctr = True,
                                   early_stopping_rounds=10,
                                   iterations = best['iterations'],
                                   learning_rate = best['learning_rate'],
                                   depth = best['depth'],
                                   l2_leaf_reg = best['l2_leaf_reg'],
                                   rsm = best['rsm'],
                                   ctr_leaf_count_limit = best['ctr_leaf_count_limit'],
                                   bootstrap_type = 'Bernoulli', # yep, its bug
                                   #subsample = params['subsample'],
                                   )

model.fit(D_train)
# Out:
# 0:	learn: 34.1663063	total: 821us	remaining: 771ms
# 1:	learn: 34.0220179	total: 2.44ms	remaining: 1.15s
# 2:	learn: 33.8784482	total: 3.31ms	remaining: 1.03s
# 3:	learn: 33.7341604	total: 4.97ms	remaining: 1.16s
# 4:	learn: 33.5852461	total: 6.89ms	remaining: 1.29s
# 5:	learn: 33.4406820	total: 9.53ms	remaining: 1.48s
# 6:	learn: 33.3076455	total: 10.3ms	remaining: 1.37s
# 7:	learn: 33.1883206	total: 11.7ms	remaining: 1.36s
# 8:	learn: 33.0661651	total: 14.1ms	remaining: 1.46s
# 9:	learn: 32.9611975	total: 17.1ms	remaining: 1.59s
# 10:	learn: 32.8485381	total: 21ms	remaining: 1.78s
# 11:	learn: 32.7432168	total: 22.9ms	remaining: 1.77s
# 12:	learn: 32.6386068	total: 24.9ms	remaining: 1.77s
# 13:	learn: 32.5339584	total: 27ms	remaining: 1.79s
# 14:	learn: 32.4183953	total: 28.9ms	remaining: 1.78s
# 15:	learn: 32.3088348	total: 31.2ms	remaining: 1.8s
# 16:	learn: 32.2056475	total: 32.5ms	remaining: 1.76s
# 17:	learn: 32.1109149	total: 34.1ms	remaining: 1.75s
# 18:	learn: 32.0053703	total: 35.4ms	remaining: 1.72s
# 19:	learn: 31.9095097	total: 36.4ms	remaining: 1.67s
# 20:	learn: 31.8028148	total: 37.8ms	remaining: 1.66s
# 21:	learn: 31.7052478	total: 39.6ms	remaining: 1.65s
# 22:	learn: 31.6044776	total: 41.4ms	remaining: 1.65s
# 23:	learn: 31.5073988	total: 44.3ms	remaining: 1.69s
# 24:	learn: 31.4104548	total: 45.8ms	remaining: 1.68s
# 25:	learn: 31.3241550	total: 47.2ms	remaining: 1.66s
# 26:	learn: 31.2295159	total: 48.5ms	remaining: 1.64s
# 27:	learn: 31.1312745	total: 50.2ms	remaining: 1.63s
# 28:	learn: 31.0352567	total: 59.7ms	remaining: 1.87s
# 29:	learn: 30.9518177	total: 61.4ms	remaining: 1.86s
# 30:	learn: 30.8600474	total: 62.9ms	remaining: 1.84s
# 31:	learn: 30.7689954	total: 65.7ms	remaining: 1.86s
# 32:	learn: 30.6828439	total: 67.9ms	remaining: 1.87s
# 33:	learn: 30.5994317	total: 69.1ms	remaining: 1.84s
# 34:	learn: 30.5148558	total: 71.1ms	remaining: 1.84s
# 35:	learn: 30.4334105	total: 73.4ms	remaining: 1.84s
# 36:	learn: 30.3552142	total: 76ms	remaining: 1.85s
# 37:	learn: 30.2789916	total: 77.3ms	remaining: 1.83s
# 38:	learn: 30.2092350	total: 89.9ms	remaining: 2.08s
# 39:	learn: 30.1462524	total: 91.8ms	remaining: 2.06s
# 40:	learn: 30.0858044	total: 93.9ms	remaining: 2.06s
# 41:	learn: 30.0185543	total: 95.6ms	remaining: 2.04s
# 42:	learn: 29.9523259	total: 97.7ms	remaining: 2.04s
# 43:	learn: 29.8752720	total: 101ms	remaining: 2.05s
# 44:	learn: 29.8134997	total: 103ms	remaining: 2.05s
# 45:	learn: 29.7430006	total: 105ms	remaining: 2.04s
# 46:	learn: 29.6780244	total: 106ms	remaining: 2.02s
# 47:	learn: 29.6197119	total: 108ms	remaining: 2s
# 48:	learn: 29.5529509	total: 109ms	remaining: 1.97s
# 49:	learn: 29.4863110	total: 110ms	remaining: 1.96s
# 50:	learn: 29.4231623	total: 113ms	remaining: 1.96s
# 51:	learn: 29.3697446	total: 114ms	remaining: 1.95s
# 52:	learn: 29.3173361	total: 116ms	remaining: 1.94s
# 53:	learn: 29.2587144	total: 117ms	remaining: 1.92s
# 54:	learn: 29.2076933	total: 119ms	remaining: 1.91s
# 55:	learn: 29.1448683	total: 121ms	remaining: 1.91s
# 56:	learn: 29.0968378	total: 126ms	remaining: 1.95s
# 57:	learn: 29.0439286	total: 127ms	remaining: 1.94s
# 58:	learn: 28.9921285	total: 129ms	remaining: 1.93s
# 59:	learn: 28.9368782	total: 130ms	remaining: 1.91s
# 60:	learn: 28.8881666	total: 133ms	remaining: 1.92s
# 61:	learn: 28.8404872	total: 136ms	remaining: 1.92s
# 62:	learn: 28.7902030	total: 138ms	remaining: 1.92s
# 63:	learn: 28.7459988	total: 139ms	remaining: 1.9s
# 64:	learn: 28.6879343	total: 143ms	remaining: 1.93s
# 65:	learn: 28.6406035	total: 145ms	remaining: 1.92s
# 66:	learn: 28.5869443	total: 148ms	remaining: 1.93s
# 67:	learn: 28.5461723	total: 151ms	remaining: 1.94s
# 68:	learn: 28.4995257	total: 155ms	remaining: 1.96s
# 69:	learn: 28.4514032	total: 160ms	remaining: 1.99s
# 70:	learn: 28.4095693	total: 163ms	remaining: 1.99s
# 71:	learn: 28.3595354	total: 165ms	remaining: 1.99s
# 72:	learn: 28.3201008	total: 167ms	remaining: 1.99s
# 73:	learn: 28.2763220	total: 170ms	remaining: 1.99s
# 74:	learn: 28.2338628	total: 173ms	remaining: 1.99s
# 75:	learn: 28.1995518	total: 177ms	remaining: 2.01s
# 76:	learn: 28.1546038	total: 179ms	remaining: 2s
# 77:	learn: 28.1138814	total: 180ms	remaining: 1.99s
# 78:	learn: 28.0697129	total: 181ms	remaining: 1.98s
# 79:	learn: 28.0323675	total: 183ms	remaining: 1.97s
# 80:	learn: 27.9978749	total: 185ms	remaining: 1.96s
# 81:	learn: 27.9499909	total: 191ms	remaining: 2s
# 82:	learn: 27.9128775	total: 194ms	remaining: 2s
# 83:	learn: 27.8771764	total: 196ms	remaining: 2s
# 132:	learn: 26.3000112	total: 315ms	remaining: 1.91s
# 133:	learn: 26.2772980	total: 319ms	remaining: 1.92s
# 134:	learn: 26.2524166	total: 320ms	remaining: 1.91s
# 135:	learn: 26.2212555	total: 322ms	remaining: 1.91s
# 136:	learn: 26.1879014	total: 325ms	remaining: 1.9s
# 137:	learn: 26.1471792	total: 326ms	remaining: 1.9s
# 138:	learn: 26.1266363	total: 328ms	remaining: 1.89s
# 139:	learn: 26.0846181	total: 330ms	remaining: 1.89s
# 140:	learn: 26.0600833	total: 332ms	remaining: 1.88s
# 141:	learn: 26.0195126	total: 334ms	remaining: 1.88s
# 142:	learn: 25.9853307	total: 336ms	remaining: 1.87s
# 143:	learn: 25.9533422	total: 337ms	remaining: 1.86s
# 144:	learn: 25.9277554	total: 339ms	remaining: 1.86s
# 145:	learn: 25.8893807	total: 340ms	remaining: 1.85s
# 146:	learn: 25.8533275	total: 342ms	remaining: 1.84s
# 147:	learn: 25.8316432	total: 343ms	remaining: 1.84s
# 148:	learn: 25.8105823	total: 345ms	remaining: 1.83s
# 149:	learn: 25.7640952	total: 347ms	remaining: 1.82s
# 150:	learn: 25.7461422	total: 350ms	remaining: 1.83s
# 151:	learn: 25.7013534	total: 352ms	remaining: 1.82s
# 152:	learn: 25.6628790	total: 353ms	remaining: 1.82s
# 153:	learn: 25.6443388	total: 356ms	remaining: 1.81s
# 154:	learn: 25.6330763	total: 357ms	remaining: 1.81s
# 155:	learn: 25.6168681	total: 360ms	remaining: 1.81s
# 156:	learn: 25.5837306	total: 366ms	remaining: 1.83s
# 157:	learn: 25.5640132	total: 368ms	remaining: 1.82s
# 158:	learn: 25.5450012	total: 372ms	remaining: 1.82s
# 159:	learn: 25.5231346	total: 375ms	remaining: 1.83s
# 160:	learn: 25.4836302	total: 377ms	remaining: 1.82s
# 161:	learn: 25.4598815	total: 380ms	remaining: 1.83s
# 162:	learn: 25.4282842	total: 383ms	remaining: 1.83s
# 163:	learn: 25.4083009	total: 385ms	remaining: 1.82s
# 164:	learn: 25.3857062	total: 387ms	remaining: 1.82s
# 165:	learn: 25.3559024	total: 388ms	remaining: 1.81s
# 166:	learn: 25.3330112	total: 390ms	remaining: 1.81s
# 167:	learn: 25.3198555	total: 393ms	remaining: 1.8s
# 168:	learn: 25.2951731	total: 394ms	remaining: 1.8s
# 169:	learn: 25.2728019	total: 396ms	remaining: 1.79s
# 170:	learn: 25.2548816	total: 399ms	remaining: 1.79s
# 171:	learn: 25.2176805	total: 401ms	remaining: 1.79s
# 172:	learn: 25.2036888	total: 404ms	remaining: 1.79s
# 173:	learn: 25.1733424	total: 405ms	remaining: 1.78s
# 174:	learn: 25.1418362	total: 406ms	remaining: 1.78s
# 175:	learn: 25.1037725	total: 409ms	remaining: 1.77s
# 176:	learn: 25.0817211	total: 410ms	remaining: 1.77s
# 177:	learn: 25.0604631	total: 412ms	remaining: 1.76s
# 178:	learn: 25.0381531	total: 414ms	remaining: 1.76s
# 179:	learn: 25.0193610	total: 415ms	remaining: 1.75s
# 323:	learn: 21.9954205	total: 720ms	remaining: 1.37s
# 324:	learn: 21.9706133	total: 721ms	remaining: 1.36s
# 325:	learn: 21.9556176	total: 723ms	remaining: 1.36s
# 326:	learn: 21.9371276	total: 725ms	remaining: 1.36s
# 327:	learn: 21.9190502	total: 726ms	remaining: 1.35s
# 328:	learn: 21.8918651	total: 731ms	remaining: 1.36s
# 329:	learn: 21.8745275	total: 733ms	remaining: 1.35s
# 330:	learn: 21.8624563	total: 737ms	remaining: 1.36s
# 331:	learn: 21.8426311	total: 739ms	remaining: 1.35s
# 332:	learn: 21.8202192	total: 740ms	remaining: 1.35s
# 333:	learn: 21.8059754	total: 742ms	remaining: 1.35s
# 334:	learn: 21.7934930	total: 743ms	remaining: 1.34s
# 335:	learn: 21.7610138	total: 746ms	remaining: 1.34s
# 336:	learn: 21.7487877	total: 747ms	remaining: 1.34s
# 337:	learn: 21.7259765	total: 749ms	remaining: 1.33s
# 338:	learn: 21.7135600	total: 750ms	remaining: 1.33s
# 339:	learn: 21.6998601	total: 752ms	remaining: 1.33s
# 340:	learn: 21.6736877	total: 753ms	remaining: 1.32s
# 341:	learn: 21.6546201	total: 755ms	remaining: 1.32s
# 342:	learn: 21.6251047	total: 756ms	remaining: 1.32s
# 343:	learn: 21.6043164	total: 758ms	remaining: 1.31s
# 344:	learn: 21.5876315	total: 760ms	remaining: 1.31s
# 345:	learn: 21.5655885	total: 761ms	remaining: 1.31s
# 346:	learn: 21.5442749	total: 763ms	remaining: 1.3s
# 347:	learn: 21.5280196	total: 765ms	remaining: 1.3s
# 348:	learn: 21.5113170	total: 766ms	remaining: 1.3s
# 349:	learn: 21.4840108	total: 769ms	remaining: 1.3s
# 350:	learn: 21.4782449	total: 771ms	remaining: 1.29s
# 351:	learn: 21.4582916	total: 772ms	remaining: 1.29s
# 352:	learn: 21.4354013	total: 774ms	remaining: 1.29s
# 353:	learn: 21.4191686	total: 776ms	remaining: 1.28s
# 354:	learn: 21.4000397	total: 777ms	remaining: 1.28s
# 355:	learn: 21.3807055	total: 779ms	remaining: 1.28s
# 356:	learn: 21.3658987	total: 781ms	remaining: 1.27s
# 357:	learn: 21.3389560	total: 783ms	remaining: 1.27s
# 358:	learn: 21.3215346	total: 785ms	remaining: 1.27s
# 359:	learn: 21.3160202	total: 786ms	remaining: 1.27s
# 360:	learn: 21.2975868	total: 787ms	remaining: 1.26s
# 361:	learn: 21.2800564	total: 796ms	remaining: 1.27s
# 362:	learn: 21.2717971	total: 798ms	remaining: 1.27s
# 363:	learn: 21.2542125	total: 799ms	remaining: 1.26s
# 364:	learn: 21.2356858	total: 801ms	remaining: 1.26s
# 365:	learn: 21.2208780	total: 804ms	remaining: 1.26s
# 366:	learn: 21.2016785	total: 806ms	remaining: 1.26s
# 367:	learn: 21.1787536	total: 808ms	remaining: 1.26s
# 368:	learn: 21.1571658	total: 810ms	remaining: 1.25s
# 369:	learn: 21.1433052	total: 814ms	remaining: 1.25s
# 370:	learn: 21.1341451	total: 816ms	remaining: 1.25s
# 371:	learn: 21.1133048	total: 817ms	remaining: 1.25s
# 372:	learn: 21.1017565	total: 829ms	remaining: 1.26s
# 373:	learn: 21.0872912	total: 830ms	remaining: 1.26s
# 374:	learn: 21.0715463	total: 831ms	remaining: 1.25s
# 375:	learn: 21.0602898	total: 833ms	remaining: 1.25s
# 376:	learn: 21.0524125	total: 835ms	remaining: 1.25s
# 377:	learn: 21.0352362	total: 836ms	remaining: 1.24s
# 378:	learn: 21.0127752	total: 839ms	remaining: 1.24s
# 379:	learn: 20.9939331	total: 840ms	remaining: 1.24s
# 380:	learn: 20.9782650	total: 842ms	remaining: 1.24s
# 381:	learn: 20.9649309	total: 844ms	remaining: 1.23s
# 382:	learn: 20.9596764	total: 846ms	remaining: 1.23s
# 383:	learn: 20.9452400	total: 847ms	remaining: 1.23s
# 384:	learn: 20.9359560	total: 849ms	remaining: 1.22s
# 385:	learn: 20.9206621	total: 851ms	remaining: 1.22s
# 386:	learn: 20.9125881	total: 853ms	remaining: 1.22s
# 387:	learn: 20.8888637	total: 856ms	remaining: 1.22s
# 388:	learn: 20.8697835	total: 857ms	remaining: 1.21s
# 389:	learn: 20.8479894	total: 859ms	remaining: 1.21s
# 390:	learn: 20.8383205	total: 861ms	remaining: 1.21s
# 391:	learn: 20.8261922	total: 862ms	remaining: 1.21s
# 392:	learn: 20.8136913	total: 865ms	remaining: 1.2s
# 393:	learn: 20.8011226	total: 868ms	remaining: 1.2s
# 394:	learn: 20.7883077	total: 871ms	remaining: 1.2s
# 395:	learn: 20.7806863	total: 873ms	remaining: 1.2s
# 396:	learn: 20.7619889	total: 875ms	remaining: 1.2s
# 397:	learn: 20.7460419	total: 876ms	remaining: 1.19s
# 398:	learn: 20.7353257	total: 877ms	remaining: 1.19s
# 399:	learn: 20.7259933	total: 878ms	remaining: 1.19s
# 400:	learn: 20.7071027	total: 880ms	remaining: 1.18s
# 401:	learn: 20.6863232	total: 882ms	remaining: 1.18s
# 402:	learn: 20.6683446	total: 883ms	remaining: 1.18s
# 403:	learn: 20.6586266	total: 885ms	remaining: 1.17s
# 404:	learn: 20.6490525	total: 887ms	remaining: 1.17s
# 405:	learn: 20.6354020	total: 889ms	remaining: 1.17s
# 406:	learn: 20.6296661	total: 890ms	remaining: 1.17s
# 407:	learn: 20.6183882	total: 892ms	remaining: 1.16s
# 408:	learn: 20.6036368	total: 894ms	remaining: 1.16s
# 409:	learn: 20.5848463	total: 895ms	remaining: 1.16s
# 410:	learn: 20.5813644	total: 897ms	remaining: 1.15s
# 411:	learn: 20.5699575	total: 899ms	remaining: 1.15s
# 412:	learn: 20.5484275	total: 902ms	remaining: 1.15s
# 413:	learn: 20.5295407	total: 904ms	remaining: 1.15s
# 414:	learn: 20.5087292	total: 907ms	remaining: 1.15s
# 415:	learn: 20.4919165	total: 912ms	remaining: 1.15s
# 416:	learn: 20.4779050	total: 913ms	remaining: 1.15s
# 417:	learn: 20.4633346	total: 914ms	remaining: 1.14s
# 418:	learn: 20.4480732	total: 917ms	remaining: 1.14s
# 419:	learn: 20.4373958	total: 919ms	remaining: 1.14s
# 420:	learn: 20.4327806	total: 920ms	remaining: 1.13s
# 421:	learn: 20.4177523	total: 922ms	remaining: 1.13s
# 422:	learn: 20.4050456	total: 924ms	remaining: 1.13s
# 423:	learn: 20.3956211	total: 925ms	remaining: 1.13s
# 424:	learn: 20.3751495	total: 926ms	remaining: 1.12s
# 425:	learn: 20.3553843	total: 936ms	remaining: 1.13s
# 426:	learn: 20.3306824	total: 938ms	remaining: 1.13s
# 427:	learn: 20.3154702	total: 939ms	remaining: 1.12s
# 428:	learn: 20.3082680	total: 940ms	remaining: 1.12s
# 429:	learn: 20.3018401	total: 942ms	remaining: 1.12s
# 430:	learn: 20.2872346	total: 944ms	remaining: 1.11s
# 431:	learn: 20.2727671	total: 946ms	remaining: 1.11s
# 432:	learn: 20.2623427	total: 947ms	remaining: 1.11s
# 433:	learn: 20.2548168	total: 949ms	remaining: 1.11s
# 434:	learn: 20.2449633	total: 951ms	remaining: 1.1s
# 435:	learn: 20.2307221	total: 953ms	remaining: 1.1s
# 436:	learn: 20.2147068	total: 954ms	remaining: 1.1s
# 437:	learn: 20.2026131	total: 956ms	remaining: 1.09s
# 438:	learn: 20.1952066	total: 957ms	remaining: 1.09s
# 439:	learn: 20.1775512	total: 960ms	remaining: 1.09s
# 440:	learn: 20.1680446	total: 961ms	remaining: 1.09s
# 441:	learn: 20.1593294	total: 963ms	remaining: 1.08s
# 442:	learn: 20.1522008	total: 964ms	remaining: 1.08s
# 443:	learn: 20.1387369	total: 966ms	remaining: 1.08s
# 444:	learn: 20.1271176	total: 969ms	remaining: 1.08s
# 445:	learn: 20.1142897	total: 974ms	remaining: 1.08s
# 446:	learn: 20.1067463	total: 975ms	remaining: 1.07s
# 447:	learn: 20.0968589	total: 977ms	remaining: 1.07s
# 448:	learn: 20.0905426	total: 979ms	remaining: 1.07s
# 449:	learn: 20.0815263	total: 985ms	remaining: 1.07s
# 450:	learn: 20.0704624	total: 989ms	remaining: 1.07s
# 451:	learn: 20.0589242	total: 991ms	remaining: 1.07s
# 452:	learn: 20.0484912	total: 993ms	remaining: 1.07s
# 453:	learn: 20.0343646	total: 994ms	remaining: 1.06s
# 454:	learn: 20.0103861	total: 997ms	remaining: 1.06s
# 455:	learn: 20.0015420	total: 999ms	remaining: 1.06s
# 456:	learn: 19.9846578	total: 1s	remaining: 1.06s
# 457:	learn: 19.9689557	total: 1s	remaining: 1.05s
# 458:	learn: 19.9531131	total: 1s	remaining: 1.05s
# 459:	learn: 19.9431479	total: 1.01s	remaining: 1.05s
# 460:	learn: 19.9241572	total: 1.01s	remaining: 1.05s
# 461:	learn: 19.9176622	total: 1.01s	remaining: 1.04s
# 462:	learn: 19.9063219	total: 1.01s	remaining: 1.04s
# 463:	learn: 19.8970792	total: 1.01s	remaining: 1.04s
# 464:	learn: 19.8786050	total: 1.01s	remaining: 1.04s
# 465:	learn: 19.8674788	total: 1.02s	remaining: 1.03s
# 466:	learn: 19.8570322	total: 1.02s	remaining: 1.03s
# 801:	learn: 16.4299165	total: 1.66s	remaining: 286ms
# 802:	learn: 16.4266112	total: 1.66s	remaining: 284ms
# 803:	learn: 16.4199314	total: 1.66s	remaining: 281ms
# 804:	learn: 16.4082617	total: 1.67s	remaining: 279ms
# 805:	learn: 16.4006095	total: 1.67s	remaining: 277ms
# 806:	learn: 16.3953407	total: 1.67s	remaining: 275ms
# 807:	learn: 16.3878048	total: 1.67s	remaining: 273ms
# 808:	learn: 16.3785000	total: 1.67s	remaining: 271ms
# 809:	learn: 16.3696708	total: 1.67s	remaining: 268ms
# 810:	learn: 16.3633035	total: 1.67s	remaining: 266ms
# 811:	learn: 16.3579534	total: 1.68s	remaining: 264ms
# 812:	learn: 16.3511284	total: 1.68s	remaining: 263ms
# 813:	learn: 16.3440855	total: 1.68s	remaining: 260ms
# 814:	learn: 16.3382069	total: 1.68s	remaining: 258ms
# 815:	learn: 16.3303572	total: 1.69s	remaining: 256ms
# 816:	learn: 16.3246160	total: 1.69s	remaining: 254ms
# 817:	learn: 16.3180949	total: 1.69s	remaining: 252ms
# 818:	learn: 16.3143162	total: 1.69s	remaining: 250ms
# 819:	learn: 16.3087470	total: 1.7s	remaining: 248ms
# 820:	learn: 16.3021048	total: 1.7s	remaining: 246ms
# 821:	learn: 16.2919447	total: 1.7s	remaining: 244ms
# 822:	learn: 16.2790239	total: 1.7s	remaining: 242ms
# 823:	learn: 16.2705871	total: 1.7s	remaining: 240ms
# 824:	learn: 16.2606220	total: 1.7s	remaining: 237ms
# 825:	learn: 16.2485613	total: 1.7s	remaining: 235ms
# 826:	learn: 16.2405236	total: 1.71s	remaining: 233ms
# 827:	learn: 16.2345753	total: 1.71s	remaining: 231ms
# 828:	learn: 16.2239087	total: 1.71s	remaining: 230ms
# 829:	learn: 16.2149350	total: 1.72s	remaining: 228ms
# 830:	learn: 16.2089808	total: 1.72s	remaining: 226ms
# 831:	learn: 16.2060683	total: 1.72s	remaining: 223ms
# 832:	learn: 16.1965240	total: 1.72s	remaining: 221ms
# 833:	learn: 16.1906062	total: 1.72s	remaining: 219ms
# 834:	learn: 16.1822650	total: 1.73s	remaining: 217ms
# 835:	learn: 16.1780280	total: 1.73s	remaining: 215ms
# 836:	learn: 16.1699261	total: 1.73s	remaining: 213ms
# 837:	learn: 16.1635242	total: 1.73s	remaining: 211ms
# 838:	learn: 16.1564621	total: 1.73s	remaining: 209ms
# 839:	learn: 16.1508894	total: 1.73s	remaining: 206ms
# 840:	learn: 16.1438511	total: 1.74s	remaining: 204ms
# 841:	learn: 16.1404589	total: 1.75s	remaining: 204ms
# 842:	learn: 16.1273040	total: 1.75s	remaining: 201ms
# 843:	learn: 16.1172947	total: 1.75s	remaining: 199ms
# 844:	learn: 16.1065313	total: 1.75s	remaining: 197ms
# 845:	learn: 16.0955369	total: 1.76s	remaining: 195ms
# 846:	learn: 16.0895049	total: 1.76s	remaining: 193ms
# 847:	learn: 16.0849180	total: 1.76s	remaining: 191ms
# 848:	learn: 16.0793643	total: 1.76s	remaining: 189ms
# 896:	learn: 15.7133318	total: 1.85s	remaining: 88.6ms
# 897:	learn: 15.6948585	total: 1.85s	remaining: 86.5ms
# 898:	learn: 15.6866716	total: 1.85s	remaining: 84.4ms
# 899:	learn: 15.6761702	total: 1.85s	remaining: 82.3ms
# 900:	learn: 15.6690963	total: 1.85s	remaining: 80.3ms
# 901:	learn: 15.6650121	total: 1.85s	remaining: 78.2ms
# 902:	learn: 15.6565725	total: 1.86s	remaining: 76.1ms
# 903:	learn: 15.6523742	total: 1.86s	remaining: 74.2ms
# 904:	learn: 15.6435104	total: 1.86s	remaining: 72.1ms
# 905:	learn: 15.6336733	total: 1.86s	remaining: 70ms
# 906:	learn: 15.6257583	total: 1.86s	remaining: 67.9ms
# 907:	learn: 15.6173988	total: 1.87s	remaining: 65.8ms
# 908:	learn: 15.6074762	total: 1.87s	remaining: 63.8ms
# 909:	learn: 15.6007100	total: 1.87s	remaining: 61.7ms
# 910:	learn: 15.5948079	total: 1.87s	remaining: 59.6ms
# 911:	learn: 15.5899157	total: 1.88s	remaining: 57.6ms
# 912:	learn: 15.5827260	total: 1.88s	remaining: 55.5ms
# 913:	learn: 15.5729987	total: 1.88s	remaining: 53.4ms
# 914:	learn: 15.5667437	total: 1.88s	remaining: 51.4ms
# 915:	learn: 15.5596636	total: 1.88s	remaining: 49.3ms
# 916:	learn: 15.5510824	total: 1.88s	remaining: 47.3ms
# 917:	learn: 15.5452140	total: 1.89s	remaining: 45.2ms
# 918:	learn: 15.5414163	total: 1.89s	remaining: 43.1ms
# 919:	learn: 15.5381630	total: 1.89s	remaining: 41.1ms
# 920:	learn: 15.5304096	total: 1.89s	remaining: 39.1ms
# 921:	learn: 15.5234283	total: 1.91s	remaining: 37.2ms
# 922:	learn: 15.5195263	total: 1.91s	remaining: 35.1ms
# 923:	learn: 15.5135538	total: 1.91s	remaining: 33.1ms
# 924:	learn: 15.5054197	total: 1.91s	remaining: 31ms
# 925:	learn: 15.5006054	total: 1.91s	remaining: 28.9ms
# 926:	learn: 15.4928560	total: 1.91s	remaining: 26.8ms
# 927:	learn: 15.4799135	total: 1.91s	remaining: 24.8ms
# 928:	learn: 15.4749027	total: 1.92s	remaining: 22.7ms
# 929:	learn: 15.4655152	total: 1.92s	remaining: 20.6ms
# 930:	learn: 15.4585070	total: 1.92s	remaining: 18.5ms
# 931:	learn: 15.4547347	total: 1.92s	remaining: 16.5ms
# 932:	learn: 15.4441947	total: 1.92s	remaining: 14.4ms
# 933:	learn: 15.4352920	total: 1.92s	remaining: 12.4ms
# 934:	learn: 15.4293834	total: 1.93s	remaining: 10.3ms
# 935:	learn: 15.4241886	total: 1.93s	remaining: 8.23ms
# 936:	learn: 15.4160406	total: 1.93s	remaining: 6.17ms
# 937:	learn: 15.4130418	total: 1.93s	remaining: 4.11ms
# 938:	learn: 15.4106511	total: 1.93s	remaining: 2.06ms
# 939:	learn: 15.4035776	total: 1.93s	remaining: 0us

# %%
#predictions:
y_pred = model.predict(X_clus_test)

# %%
y_pred.shape
# Out:
# (52,)
