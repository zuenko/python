# %%
import numpy as np, pandas as pd

# %% [markdown]
# ### Load

# %%
df = pd.read_csv('data/train.tsv', sep='\t', quotechar=' ', header = None).fillna('-')
df.columns = ['context_id', 'context_2', 'context_1', 'context_0', 'reply_id', 'reply', 'label', 'confidence']
test = pd.read_csv('data/public.tsv', sep='\t', quotechar = ' ', header = None).fillna('-')
test.columns = ['context_id', 'context_2', 'context_1', 'context_0', 'reply_id', 'reply']

# %%
df.head()
# Out:
#     context_id                                          context_2  \
# 0  22579918886  кликни на меня а потом на надпись " видео - зв...
# 1  22579918886  кликни на меня а потом на надпись " видео - зв...
# 2  22579918886  кликни на меня а потом на надпись " видео - зв...
# 3  22579918886  кликни на меня а потом на надпись " видео - зв...
# 4  22579918886  кликни на меня а потом на надпись " видео - зв...
#
#            context_1                context_0  reply_id  \
# 0  о , я тебя вижу .  ладно , повесь трубку .         0
# 1  о , я тебя вижу .  ладно , повесь трубку .         1
# 2  о , я тебя вижу .  ладно , повесь трубку .         2
# 3  о , я тебя вижу .  ладно , повесь трубку .         3
# 4  о , я тебя вижу .  ладно , повесь трубку .         4
#
#                       reply  label  confidence
# 0                 не могу .      2    0.875352
# 1    нет , звонить буду я .      1    0.900968
# 2  слушай , я не мог уйти .      0    0.884320
# 3   я не прекращу звонить .      2    0.982530
# 4              я звоню им .      2    0.838054

# %%
def label_enc(x ,reverse = False):
    if reverse == False:
        if x == 'bad':
            return 0
        elif x == 'neutral':
            return 1
        else:
            return 2
    else:
        if x == 0:
            return 'bad'
        elif x == 1:
            return 'neutral'
        else:
            return 'good'
df['label'] = df['label'].apply(lambda x: label_enc(x))

# %%
from keras.preprocessing.text import Tokenizer, hashing_trick
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, LSTM, Bidirectional
# Out:
# /home/denis/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.model_selection import train_test_split

import scipy.sparse as sps

# %%
df[[col for col in df.columns if col not in ['label', 'confidence']]]
# Out:
#             context_id                                          context_2  \
# 0          22579918886  кликни на меня а потом на надпись " видео - зв...
# 1          22579918886  кликни на меня а потом на надпись " видео - зв...
# 2          22579918886  кликни на меня а потом на надпись " видео - зв...
# 3          22579918886  кликни на меня а потом на надпись " видео - зв...
# 4          22579918886  кликни на меня а потом на надпись " видео - зв...
# 5          22579918886  кликни на меня а потом на надпись " видео - зв...
# 6          50117448291                                 бывало и получше .
# 7          50117448291                                 бывало и получше .
# 8          50117448291                                 бывало и получше .
# 9          50117448291                                 бывало и получше .
# 10         50117448291                                 бывало и получше .
# 11         50117448291                                 бывало и получше .
# 12         72855813972                                 ну , это не ново .
# 13         72855813972                                 ну , это не ново .
# 14         72855813972                                 ну , это не ново .
# 15         72855813972                                 ну , это не ново .
# 16         72855813972                                 ну , это не ново .
# 17         72855813972                                 ну , это не ново .
# 18         76323501777                                              ага .
# 19         76323501777                                              ага .
# 20         76323501777                                              ага .
# 21         76323501777                                              ага .
# 22         76323501777                                              ага .
# 23         76323501777                                              ага .
# 24        127768564286  как вы предпочитаете " похищенные " или " подо...
# 25        127768564286  как вы предпочитаете " похищенные " или " подо...
# 26        127768564286  как вы предпочитаете " похищенные " или " подо...
# 27        127768564286  как вы предпочитаете " похищенные " или " подо...
# 28        127768564286  как вы предпочитаете " похищенные " или " подо...
# 29        127768564286  как вы предпочитаете " похищенные " или " подо...
# ...                ...                                                ...
# 97503  281420667347488                               давай . ударь меня .
# 97504  281420667347488                               давай . ударь меня .
# 97518                                   какого дьявола ?
# 97519                                   какого дьявола ?
# 97520                                   какого дьявола ?
# 97521                                     давай оттуда !
# 97522                                     давай оттуда !
# 97523                                     давай оттуда !
# 97524                                     давай оттуда !
# 97525                                     давай оттуда !
# 97526                                     давай оттуда !
# 97527                               меня зовут спенсер .
# 97528                               меня зовут спенсер .
# 97529                               меня зовут спенсер .
# 97530                               меня зовут спенсер .
# 97531                               меня зовут спенсер .
# 97532                               меня зовут спенсер .
#
#                                                context_0  reply_id  \
# 0                                ладно , повесь трубку .         0
# 1                                ладно , повесь трубку .         1
# 2                                ладно , повесь трубку .         2
# 3                                ладно , повесь трубку .         3
# 4                                ладно , повесь трубку .         4
# 5                                ладно , повесь трубку .         5
# 6      я пытаюсь добраться до юджина , но , кажется ,...         0
# 7      я пытаюсь добраться до юджина , но , кажется ,...         1
# 8      я пытаюсь добраться до юджина , но , кажется ,...         2
# 9      я пытаюсь добраться до юджина , но , кажется ,...         3
# 10     я пытаюсь добраться до юджина , но , кажется ,...         4
# 11     я пытаюсь добраться до юджина , но , кажется ,...         5
# 12                              знаю только понаслышке .         0
# 13                              знаю только понаслышке .         1
# 14                              знаю только понаслышке .         2
# 15                              знаю только понаслышке .         3
# 16                              знаю только понаслышке .         4
# 17                              знаю только понаслышке .         5
# 18                                        да , хорошим .         0
# 19                                        да , хорошим .         1
# 20                                        да , хорошим .         2
# 21                                        да , хорошим .         3
# 22                                        да , хорошим .         4
# 23                                        да , хорошим .         5
# 24                          мне больше нравится второе .         0
# 25                          мне больше нравится второе .         1
# 26                          мне больше нравится второе .         2
# 27                          мне больше нравится второе .         3
# 28                          мне больше нравится второе .         4
# 29                          мне больше нравится второе .         5
# ...                                                  ...       ...
# 97503   и не надо недооценивать силу обычного человека .         0
# 97504   и не надо недооценивать силу обычного человека .         1
# 97505   и не надо недооценивать силу обычного человека .         2
# 97506   и не надо недооценивать силу обычного человека .         3
# 97507   и не надо недооценивать силу обычного человека .         4
# 97508   и не надо недооценивать силу обычного человека .         5
# 97509                                не вкусно - то чё !         0
# 97510                                не вкусно - то чё !         1
# 97511                                не вкусно - то чё !         2
# 97512                                не вкусно - то чё !         3
# 97513                                не вкусно - то чё !         4
# 97514                                не вкусно - то чё !         5
# 97515                             вы вызвали меня сюда .         0
# 97516                             вы вызвали меня сюда .         1
# 97517                             вы вызвали меня сюда .         2
# 97518                             вы вызвали меня сюда .         3
# 97519                             вы вызвали меня сюда .         4
# 97520                             вы вызвали меня сюда .         5
# 97521                                           ты там ?         0
# 97522                                           ты там ?         1
# 97523                                           ты там ?         2
# 97524                                           ты там ?         3
# 97525                                           ты там ?         4
# 97526                                           ты там ?         5
# 97527                              я окружной прокурор .         0
# 97528                              я окружной прокурор .         1
# 97529                              я окружной прокурор .         2
# 97530                              я окружной прокурор .         3
# 97531                              я окружной прокурор .         4
# 97532                              я окружной прокурор .         5
#
#                                                    reply
# 0                                              не могу .
# 1                                 нет , звонить буду я .
# 2                               слушай , я не мог уйти .
# 3                                я не прекращу звонить .
# 4                                           я звоню им .
# 5                                 просто повесь трубку .
# 6                                                едете ?
# 7                                                 едем .
# 8                             куда же вы едете , месье ?
# 9                          берите бутылку , а мы такси .
# 10     господи , куда же это вы решили отправиться пе...
# 11                                                куда ?
# 12                                       зато я слышал .
# 13                    я слышал , там многое изменилось .
# 14                                 но видел фотографии .
# 15                             оттуда видно всю долину .
# 16                                я там пел на террасе .
# 17                               а я слышал , и не раз .
# 18                                             хороший .
# 19                                        он разбил её .
# 20                          ему было хреново , дорогая .
# 21     помнишь , как у него фокусы никогда не получал...
# 22          джимми думал , что ему удастся выкрутиться .
# 23                                клара , мне так жаль .
# 24                      вы мне тоже нравитесь , доктор .
# 25                                            мне тоже .
# 26                          а я предпочитаю " лайнел " .
# 27                            но мне тоже это нравится .
# 28                               забавно , но мне тоже .
# 29                               я выбираю достоинство .
# ...                                                  ...
# 97503            тогда мне стоит начать его отстаивать .
# 97504                          я не человек и не зверь .
# 97505  если ты не станешь сражаться . . . то погибнешь .
# 97506                       не надо недооценивать себя .
# 97507      самое ужасное , что ты видишь во мне жертву .
# 97508         всё зависит от того , на что ты способен .
# 97509                                не вкусно - то чё !
# 97510                       ну , он не очень съедобный .
# 97511                 он собирается убить тебя , скотт .
# 97512                                           лежать !
# 97513                                 он очень горячий .
# 97514                       ты не должна была это есть !
# 97515                                         это ложь .
# 97516  наоборот , я допрашиваю вас , но предпочел бы ...
# 97517                                     я сам пришёл .
# 97518                                 я отнес вас сюда .
# 97519                          ваша дочь впустила меня .
# 97520                           вы пришли в мое здание .
# 97521                                   да , я уже там .
# 97522                               а где мне еще быть ?
# 97523                                 нет , я уже дома .
# 97524                         да , только что подъехал .
# 97525                                               да .
# 97526                                   ты ведь не там ?
# 97527                            заместитель прокурора .
# 97528  мистер томпсон , вы арестованы за фальсификаци...
# 97529                              я окружной прокурор .
# 97530                                          куратор .
# 97531                                         прокурор .
# 97532          детектив огилви , приятно познакомиться .
#
# [97533 rows x 6 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df[[col for col in df.columns if col not in ['label', 'confidence']]], df['label'], train_size=0.3)
# Out:
# /home/denis/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
def batch_generator(X, y, batch_size, shuffle):
    number_of_batches = X.shape[0]/batch_size
    counter = 0
    sample_index = np.arange(X.shape[0])
    if shuffle:
        np.random.shuffle(sample_index)
    while True:
        batch_index = sample_index[batch_size*counter:batch_size*(counter+1)]
        X_batch = X[batch_index,:].toarray()
        y_batch = y[batch_index]
        counter += 1
        yield X_batch, y_batch
        if (counter == number_of_batches):
            if shuffle:
                np.random.shuffle(sample_index)
            counter = 0

# %%
model = Sequential()
model.add(Embedding(100, 128, input_length=4194304))
model.add(Bidirectional(LSTM(32)))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# try using different optimizers and different optimizer configs
model.compile('adam', 'binary_crossentropy', metrics=['accuracy'])

print('Train...')
model.fit_generator(generator=batch_generator(X_test, y_test, 32, True),
                                    nb_epoch=3,
                                    samples_per_epoch=X_train.shape[0])
# Out:
# Train...
# /home/denis/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   del sys.path[0]
# /home/denis/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(generator=<generator..., steps_per_epoch=29259, epochs=3)`
#   del sys.path[0]
# Epoch 1/3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-6f09dc49cdaa> in <module>()
#      11 model.fit_generator(generator=batch_generator(X_test, y_test, 32, True),
#      12                                     nb_epoch=3,
# ---> 13                                     samples_per_epoch=X_train.shape[0])
#
# ~/anaconda3/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/lib/python3.6/site-packages/keras/models.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1274                                         use_multiprocessing=use_multiprocessing,
#    1275                                         shuffle=shuffle,
# -> 1276                                         initial_epoch=initial_epoch)
#    1277
#    1278     @interfaces.legacy_generator_methods_support
#
# ~/anaconda3/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2190                 batch_index = 0
#    2191                 while steps_done < steps_per_epoch:
# -> 2192                     generator_output = next(output_generator)
#    2193
#    2194                     if not hasattr(generator_output, '__len__'):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py in get(self)
#     791             success, value = self.queue.get()
#     792             if not success:
# --> 793                 six.reraise(value.__class__, value, value.__traceback__)
#
# ~/anaconda3/lib/python3.6/site-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# ~/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py in _data_generator_task(self)
#     656                             # => Serialize calls to
#     657                             # infinite iterator/generator's next() function
# --> 658                             generator_output = next(self._generator)
#     659                             self.queue.put((True, generator_output))
#     660                         else:
#
# <ipython-input-12-7726f0d203cd> in batch_generator(X, y, batch_size, shuffle)
#       7     while True:
#       8         batch_index = sample_index[batch_size*counter:batch_size*(counter+1)]
# ----> 9         X_batch = X[batch_index,:].toarray()
#      10         y_batch = y[batch_index]
#      11         counter += 1
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1838         """Return the cached item, item represents a label indexer."""
#    1839         cache = self._item_cache
# -> 1840         res = cache.get(item)
#    1841         if res is None:
#    1842             values = self._data.get(item)
#
# TypeError: unhashable type: 'numpy.ndarray'
